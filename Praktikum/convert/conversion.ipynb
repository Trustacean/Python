# %%
# a program to convert temperature from one scale to another scale
# author : Edward Vito Brata Y
# ver 1.1.0
# 17th March 2023

run=1

while run==1:
    #loop to start over if the user wants to convert another value
    
    correction1=1
    while correction1==1:
        #loop to check if the choice is valid (only 1-4)
        #prints to guide the user
        print ("Celsius Conversion Program")
        print ("""Convert from?
1. Celsius
2. Reaumur
3. Fahrenheit
4. kelvin
        """)
        initialChoice=int(input("Please select your choice! :"))
        #user's choice input
        if initialChoice == 1:
            correction1=0
            initialValue=int(input("Please enter the initial value! :"))
            #input value to convert
            converted=initialValue/5
            #half of the conversion formula
        elif initialChoice == 2:
            correction1=0
            initialValue=int(input("Please enter the initial value! :"))
            #input value to convert
            converted=initialValue/4
            #half of the conversion formula
        elif initialChoice == 3:
            correction1=0
            initialValue=int(input("Please enter the initial value! :"))
            #input value to convert
            converted=(initialValue-32)/9
            #half of the conversion formula
        elif initialChoice == 4:
            correction1=0
            initialValue=int(input("Please enter the initial value! :"))
            #input value to convert
            converted=(initialValue-273)/5
            #half of the conversion formula
        else:
            print ("Invalid choice!, please select only between 1 to 4!")
            
            
    #prints to guide the user
    print ("Convert to?")
    print ("1. Celsius")
    print ("2. Reaumur")
    print ("3. Fahrenheit")
    print ("4. kelvin")
    
    correction2=1
    while correction2==1: 
        #loop to check if the choice is valid (only 1-4)
        choice = int (input("Please select your choice :")) 
        #user's choice input
        
        if choice ==1:
            correction2=0
            converted = converted * 5
            #conversion formula
            print ("The converted value is ", converted)
            #prints the converted value
            next=input("Convert another value? (y/n)") 
            #choice to start over if the user wants to convert another value
            if next == "y":     
                #conditions if user wants to convert another value
                continue
            else:
                run = 0         
                #exits the program by disabling loop
                
        elif choice == 2: #conditions
            correction2=0
            converted = converted * 4                       
            #conversion formula
            print ("The converted value is ", converted)    
            #prints the converted value
            next=input("Convert another value? (y/n)")      
            #choice to start over if the user wants to convert another value
            if next == "y":     
                #conditions if user wants to convert another value
                continue
            else:
                run = 0         
                #exits the program by disabling loop
                
        elif choice == 3:
            correction2=0
            converted = (converted * 9) + 32                  
            #conversion formula
            print ("The converted value is ", converted)    
            #prints the converted value
            next=input("Convert another value? (y/n)")      
            #choice to start over if the user wants to convert another value
            if next == "y":     
                #conditions if user wants to convert another value
                continue
            else:
                run = 0         
                #exits the program by disabling loop
                
        elif choice == 4:
            correction2=0
            converted = (converted * 5) + 273                         
            #conversion formula
            print ("The converted value is ", converted)    
            #prints the converted value
            next=input("Convert another value? (y/n)")      
            #choice to start over if the user wants to convert another value
            if next == "y":     
                #conditions if user wants to convert another value
                continue
            else:
                run = 0         
                #exits the program by disabling loop
                
        else :    
            print ("Please enter a valid choice!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       1 # a program to convert temperature from one scale to another scale
#       2 # author : Edward Vito Brata Y
#       3 # ver 1.1.0
#       4 # 17th March 2023
# ----> 6 while run==1:
#       7     #loop to start over if the user wants to convert another value
#       9     correction1=1
#      10     while correction1==1:
#      11         #loop to check if the choice is valid (only 1-4)
#      12         #prints to guide the user
#
# NameError: name 'run' is not defined
